# %% [markdown]
# ## Verificar conectividad con la base de datos de MongoDB Atlas
#
# El presente cuaderno de trabajo corresponde a un script obtenido de la propia página de MongoDB atlas, que verifica conectividad con la base de datos.

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
from dotenv import find_dotenv, load_dotenv
import os

# Encontrar .env y cargarlo
load_dotenv(find_dotenv())

# Credenciales
db_user = os.getenv("DB_USER_T")
db_pass = os.getenv("DB_PASS_T")
db_cluster = os.getenv("DB_CLUSTER_T")

uri = rf"mongodb+srv://{db_user}:{db_pass}@{db_cluster.lower()}.gypwd.mongodb.net/?retryWrites=true&w=majority&appName={db_cluster}"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!
